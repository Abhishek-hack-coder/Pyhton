# %%
22+33
# Out:
# 55

# %%
5-2
# Out:
# 3

# %%
4//2
# Out:
# 2

# %%
4/2
# Out:
# 2.0

# %%
7%3
# Out:
# 1

# %%
5*6
# Out:
# 30

# %%
3+2
4+6
# Out:
# 10

# %%
x=0
if(x>0):
    print("positive")
elif(x==0):
    print("zero")
else:
    print("negative")
# Out:
# zero

# %%
import matplotlib.animation as animation
print(animation.writers.list())
# Out:
# ['pillow', 'html']

# %%
import pandas as pd
import os
os.getcwd()
# Out:
# 'C:\\Users\\goela'

# %%
os.listdir(os.getcwd())
# Out:
# ['.conda',
#  '.condarc',
#  '.ipynb_checkpoints',
#  '.ipython',
#  '.jupyter',
#  '2018_Sales_Total_Tabs.xlsx',
#  '3D Objects',
#  'Anaconda3',
#  'AppData',
#  'Application Data',
#  'bigmart_data.csv',
#  'capitals.csv',
#  'capitals.xlsx',
#  'Contacts',
#  'Cookies',
#  'data.csv',
#  'database.ipynb',
#  'Desktop',
#  'Documents',
#  'Downloads',
#  'Favorites',
#  'IntelGraphicsProfiles',
#  'Linear Regression.ipynb',
#  'Links',
#  'Local Settings',
#  'MicrosoftEdgeBackups',
#  'MSE.ipynb',
#  'Music',
#  'My Documents',
#  'NetHood',
#  'NTUSER.DAT',
#  'ntuser.dat.LOG1',
#  'ntuser.dat.LOG2',
#  'NTUSER.DAT{703521e4-9dc1-11ea-a57a-80c9a67ed98b}.TxR.0.regtrans-ms',
#  'NTUSER.DAT{703521e4-9dc1-11ea-a57a-80c9a67ed98b}.TxR.1.regtrans-ms',
#  'NTUSER.DAT{703521e4-9dc1-11ea-a57a-80c9a67ed98b}.TxR.2.regtrans-ms',
#  'NTUSER.DAT{703521e4-9dc1-11ea-a57a-80c9a67ed98b}.TxR.blf',
#  'NTUSER.DAT{703521e5-9dc1-11ea-a57a-80c9a67ed98b}.TM.blf',
# ...

# %%
pd.read_csv('bigmart_data.csv')
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
pd.read_csv('C:\\Users\\goela\\bigmart_data.csv')
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...
