# %%
import pandas as pd
data=pd.read_excel("SampleData.xlsx",skiprows=3)
data.head()
# Out:
#    3  M    65  Central    68 Central.1      Arts     64  Comm&Mgmt   No  \
# 0  4  M  56.0  Central  52.0   Central   Science  52.00   Sci&Tech   No
# 1  5  M  85.8  Central  73.6   Central  Commerce  73.30  Comm&Mgmt   No
# 2  6  M  55.0   Others  49.8    Others   Science  67.25   Sci&Tech  Yes
# 3  7  F  46.0   Others  49.2    Others  Commerce  79.00  Comm&Mgmt   No
# 4  8  M  82.0  Central  64.0   Central   Science  66.00   Sci&Tech  Yes
#
#       75  Mkt&Fin   57.8      Placed    250000
# 0  66.00   Mkt&HR  59.43  Not Placed       NaN
# 1  96.80  Mkt&Fin  55.50      Placed  425000.0
# 2  55.00  Mkt&Fin  51.58  Not Placed       NaN
# 3  74.28  Mkt&Fin  53.29  Not Placed       NaN
# 4  67.00  Mkt&Fin  62.14      Placed  252000.0

# %%
import pandas as pd
capitals=pd.DataFrame([['Punjab','Chandigarh'],['Uttar Pradesh','Lucknow'],['TamilNadu','Agartala']],columns=['State','Capital'])
capitals.to_excel('capitals.xlsx')
capitals
# Out:
#            State     Capital
# 0         Punjab  Chandigarh
# 1  Uttar Pradesh     Lucknow
# 2      TamilNadu    Agartala

# %%
import pandas as pd
capitals=pd.DataFrame([['Punjab','Chandigarh'],['Uttar Pradesh','Lucknow'],['TamilNadu','Agartala']],columns=['State','Capital'])
capitals.to_csv('capitals.csv')

# %%
data=pd.read_csv("capitals.csv")
data
# Out:
#    Unnamed: 0          State     Capital
# 0           0         Punjab  Chandigarh
# 1           1  Uttar Pradesh     Lucknow
# 2           2      TamilNadu    Agartala

# %%
data=pd.read_csv("bigmart_data.csv")
data
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
import csv
with open('capitals.csv','rt')as f:
    data = csv.reader(f)
    for row in data:
        print(row)
# Out:
# ['', 'State', 'Capital']
# ['0', 'Punjab', 'Chandigarh']
# ['1', 'Uttar Pradesh', 'Lucknow']
# ['2', 'TamilNadu', 'Agartala']

# %%
import csv
with open('capitals.csv', mode='w') as file:
    writer = csv.writer(file, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
    writer.writerow(['State','Capital'])
    writer.writerow(['Manipur','Imphal'])
    writer.writerow(['Gujarat','Gandhinagar'])
    writer.writerow(['Bihar','Patna'])

# %%
import csv
with open('capitals.csv','rt')as f:
    data = csv.reader(f)
    for row in data:
        print(row)
# Out:
# ['State', 'Capital']
# []
# ['Manipur', 'Imphal']
# []
# ['Gujarat', 'Gandhinagar']
# []
# ['Bihar', 'Patna']
# []

# %%
# Out:
#   File "<ipython-input-13-80423ab5abe7>", line 18
#     if guess < 1 or guess > 100:
#            ^
# SyntaxError: name 'c' is assigned to before global declaration

# %%
import random
def game():
    num = random.randrange(1,100)
    guess=int(input(" enter the number"))
    while guess!=num:
        if guess<num:
            print("go higher for the random number. try again")
            guess=int(input(" enter the number"))
        elif guess>num:
            print(" go lower for the random number. try again")
            guess=(int(input(" enter the number")))
        else:
            print(" please enter valid number. try again")
    while guess==num:
        print("congratuation you got the real value of random number")
        break
c="yes"
def main():
    global c
    while c=="yes":
        game()
        c=input("Wanna play more(yes/no):")
main()
# Out:
#  enter the number55
#  go lower for the random number. try again
#  enter the number45
#  go lower for the random number. try again
#  enter the number35
#  go lower for the random number. try again
#  enter the number25
#  go lower for the random number. try again
#  enter the number5
# go higher for the random number. try again
#  enter the number10
# go higher for the random number. try again
#  enter the number15
#  go lower for the random number. try again
#  enter the number11
# go higher for the random number. try again
#  enter the number13
# go higher for the random number. try again
#  enter the number14
# congratuation you got the real value of random number
# Wanna play more(yes/no):yes
#  enter the number1
# go higher for the random number. try again
#  enter the number41
# go higher for the random number. try again
#  enter the number51
# go higher for the random number. try again
#  enter the number71
# go higher for the random number. try again
#  enter the number81
# ...
